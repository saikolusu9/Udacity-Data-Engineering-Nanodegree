# %%
config = configparser.ConfigParser()
config.read('credentials.cfg')
os.environ['AWS_ACCESS_KEY_ID']=config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY']=config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
import os
import boto3
import pandas as pd
import sys
from io import StringIO

# %% [markdown]
# ## Read Datasets

# %%
def get_data_from_s3(foldername, filename):
    client = boto3.client('s3')
    bucket_name = 'spark-project-kolusu'
    object_key = "/".join(["input",foldername,filename])
    csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')
    df = pd.read_csv(StringIO(csv_string), low_memory=False)
    return df

# %%
df_Crashes = get_data_from_s3("Crashes","Crashes.csv")
df_Vehicles = get_data_from_s3("Vehicles","Vehicles.csv")
df_Persons = get_data_from_s3("Persons","Persons.csv")

# %% [markdown]
# ## Explore Datasets

# %% [markdown]
# ### Check the number of records in each table

# %%
print("The number of records in collisions data set is %d" %len(df_Crashes))
# Out:
# The number of records in collisions data set is 1827692

# %%
print("The number of records in vehicles data set is %d" %len(df_Vehicles))
# Out:
# The number of records in vehicles data set is 3664394

# %%
print("The number of records in persons data set is %d" %len(df_Persons))
# Out:
# The number of records in persons data set is 4452223

# %% [markdown]
# ### Get the summary of each table

# %%
df_Crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827692 entries, 0 to 1827691
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   crash_date                     object
#  1   crash_time                     object
#  2   on_street_name                 object
#  3   number_of_persons_injured      float64
#  4   number_of_persons_killed       float64
#  5   number_of_pedestrians_injured  int64
#  6   number_of_pedestrians_killed   int64
#  7   number_of_cyclist_injured      int64
#  8   number_of_cyclist_killed       int64
#  9   number_of_motorist_injured     int64
#  10  number_of_motorist_killed      int64
#  11  contributing_factor_vehicle_1  object
#  12  contributing_factor_vehicle_2  object
#  13  collision_id                   int64
#  14  vehicle_type_code1             object
#  15  vehicle_type_code2             object
#  16  borough                        object
#  17  zip_code                       object
#  18  latitude                       float64
#  19  longitude                      float64
#  20  location                       object
#  21  cross_street_name              object
#  22  off_street_name                object
#  23  contributing_factor_vehicle_3  object
#  24  contributing_factor_vehicle_4  object
#  25  vehicle_type_code_3            object
#  26  vehicle_type_code_4            object
#  27  contributing_factor_vehicle_5  object
#  28  vehicle_type_code_5            object
# dtypes: float64(4), int64(7), object(18)
# memory usage: 404.4+ MB

# %%
df_Vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3664394 entries, 0 to 3664393
# Data columns (total 25 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   unique_id                    int64
#  1   collision_id                 int64
#  2   crash_date                   object
#  3   crash_time                   object
#  4   vehicle_id                   object
#  5   state_registration           object
#  6   vehicle_type                 object
#  7   contributing_factor_1        object
#  8   vehicle_make                 object
#  9   vehicle_year                 float64
#  10  travel_direction             object
#  11  vehicle_occupants            float64
#  12  driver_sex                   object
#  13  driver_license_status        object
#  14  driver_license_jurisdiction  object
#  15  pre_crash                    object
#  16  point_of_impact              object
#  17  vehicle_damage               object
#  18  public_property_damage       object
#  19  contributing_factor_2        object
#  20  vehicle_damage_1             object
#  21  vehicle_damage_2             object
#  22  vehicle_damage_3             object
#  23  vehicle_model                object
#  24  public_property_damage_type  object
# dtypes: float64(2), int64(2), object(21)
# memory usage: 698.9+ MB

# %%
df_Persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4452223 entries, 0 to 4452222
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   unique_id              int64
#  1   collision_id           int64
#  2   crash_date             object
#  3   crash_time             object
#  4   person_id              object
#  5   person_type            object
#  6   person_injury          object
#  7   vehicle_id             float64
#  8   ped_role               object
#  9   person_sex             object
#  10  person_age             float64
#  11  ejection               object
#  12  emotional_status       object
#  13  bodily_injury          object
#  14  position_in_vehicle    object
#  15  safety_equipment       object
#  16  complaint              object
#  17  ped_location           object
#  18  ped_action             object
#  19  contributing_factor_1  object
#  20  contributing_factor_2  object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 713.3+ MB

# %% [markdown]
# ### Check for Missing Values

# %%
df_Crashes.isnull().any()
# Out:
# crash_date                       False
# crash_time                       False
# on_street_name                    True
# number_of_persons_injured         True
# number_of_persons_killed          True
# number_of_pedestrians_injured    False
# number_of_pedestrians_killed     False
# number_of_cyclist_injured        False
# number_of_cyclist_killed         False
# number_of_motorist_injured       False
# number_of_motorist_killed        False
# contributing_factor_vehicle_1     True
# contributing_factor_vehicle_2     True
# collision_id                     False
# vehicle_type_code1                True
# vehicle_type_code2                True
# borough                           True
# zip_code                          True
# latitude                          True
# longitude                         True
# location                          True
# cross_street_name                 True
# off_street_name                   True
# contributing_factor_vehicle_3     True
# contributing_factor_vehicle_4     True
# vehicle_type_code_3               True
# vehicle_type_code_4               True
# contributing_factor_vehicle_5     True
# vehicle_type_code_5               True
# dtype: bool

# %%
df_Vehicles.isnull().any()
# Out:
# unique_id                      False
# collision_id                   False
# crash_date                     False
# crash_time                     False
# vehicle_id                     False
# state_registration              True
# vehicle_type                    True
# contributing_factor_1           True
# vehicle_make                    True
# vehicle_year                    True
# travel_direction                True
# vehicle_occupants               True
# driver_sex                      True
# driver_license_status           True
# driver_license_jurisdiction     True
# pre_crash                       True
# point_of_impact                 True
# vehicle_damage                  True
# public_property_damage          True
# contributing_factor_2           True
# vehicle_damage_1                True
# vehicle_damage_2                True
# vehicle_damage_3                True
# vehicle_model                   True
# public_property_damage_type     True
# dtype: bool

# %%
df_Persons.isnull().any()
# Out:
# unique_id                False
# collision_id             False
# crash_date               False
# crash_time               False
# person_id                 True
# person_type              False
# person_injury            False
# vehicle_id                True
# ped_role                  True
# person_sex                True
# person_age                True
# ejection                  True
# emotional_status          True
# bodily_injury             True
# position_in_vehicle       True
# safety_equipment          True
# complaint                 True
# ped_location              True
# ped_action                True
# contributing_factor_1     True
# contributing_factor_2     True
# dtype: bool

# %%
df_Persons["person_id"].isnull().sum()
# Out:
# 19

# %%
df_Persons[df_Persons["person_id"].isnull()]
# Out:
#          unique_id  collision_id               crash_date crash_time  \
# 49026      5505096       3867504  2018-03-22T00:00:00.000      16:50
# 720721     5238969       3904727  2018-05-19T00:00:00.000      19:59
# 948660     5270154       3884772  2018-04-19T00:00:00.000      12:20
# 1083898    5231134       3902330  2018-05-11T00:00:00.000       2:20
M  ...  Not Ejected   Does Not Apply        Does Not Apply
# 3398583          M  ...  Not Ejected   Does Not Apply        Does Not Apply
# 3434976        NaN  ...          NaN              NaN                   NaN
#
#                                        position_in_vehicle  \
# 49026                                                  NaN
# 720721                                              Driver
# 948660                                              Driver
# 1083898                                             Driver
# 1205662                                             Driver
# 1387279  Front passenger, if two or more persons, inclu...
# 1695412  Front passenger, if two or more persons, inclu...
# 1885224                                             Driver
# 2054551  Front passenger, if two or more persons, inclu...
# 2105902                                             Driver
# 2151741  Front passenger, if two or more persons, inclu...
# 2623022                                             Driver
# 2691643                                             Driver
# 2892223                                             Driver
# 2967313  Front passenger, if two or more persons, inclu...
# 3007360  Front passenger, if two or more persons, inclu...
# 3352603  Front passenger, if two or more persons, inclu...
# 3398583                                             Driver
# 3434976                                                NaN
#
#            safety_equipment               complaint  \
# 49026                   NaN  Fracture - Dislocation
# 720721   Lap Belt & Harness  Fracture - Dislocation
# 948660   Lap Belt & Harness          Does Not Apply
# 1083898  Lap Belt & Harness          Does Not Apply
# 1205662  Lap Belt & Harness      Contusion - Bruise
# 1387279  Lap Belt & Harness          Does Not Apply
# 1695412  Lap Belt & Harness          Does Not Apply
# 1885224  Lap Belt & Harness          Does Not Apply
# 2054551            Lap Belt          Does Not Apply
# 2105902  Lap Belt & Harness          Does Not Apply
# 2151741  Lap Belt & Harness          Does Not Apply
# 2623022                None          Does Not Apply
# 2691643            Lap Belt          Does Not Apply
# 2892223            Lap Belt          Does Not Apply
# 2967313  Lap Belt & Harness          Does Not Apply
# 3007360                None              Concussion
# 3352603  Lap Belt & Harness          Does Not Apply
# 3398583            Lap Belt          Does Not Apply
# 3434976                 NaN                     NaN
#
#                                               ped_location  \
# 49026    Pedestrian/Bicyclist/Other Pedestrian Not at I...
# 720721                                                 NaN
# 948660                                                 NaN
# 1083898                                                NaN
# 1205662                                                NaN
# 1387279                                                NaN
# 1695412                                                NaN
# 1885224                                                NaN
# 2054551                                                NaN
# 2105902                                                NaN
# 2151741                                                NaN
# 2623022                                                NaN
# 2691643                                                NaN
# 2892223                                                NaN
# 2967313                                                NaN
# 3007360                                                NaN
# 3352603                                                NaN
# 3398583                                                NaN
# 3434976                                                NaN
#
#                        ped_action contributing_factor_1 contributing_factor_2
# 49026    Other Actions in Roadway                   NaN                   NaN
# 720721                        NaN                   NaN                   NaN
# 948660                        NaN                   NaN                   NaN
# 1083898                       NaN                   NaN                   NaN
# 1205662                       NaN                   NaN                   NaN
# 1387279                       NaN                   NaN                   NaN
# 1695412                       NaN                   NaN                   NaN
# 1885224                       NaN                   NaN                   NaN
# 2054551                       NaN                   NaN                   NaN
# 2105902                       NaN                   NaN                   NaN
# 2151741                       NaN                   NaN                   NaN
# 2623022                       NaN                   NaN                   NaN
# 2691643                       NaN                   NaN                   NaN
# 2892223                       NaN                   NaN                   NaN
# 2967313                       NaN                   NaN                   NaN
# 3007360                       NaN                   NaN                   NaN
# 3352603                       NaN                   NaN                   NaN
# 3398583                       NaN                   NaN                   NaN
# 3434976                       NaN                   NaN                   NaN
#
# [19 rows x 21 columns]

# %%
df_Persons.duplicated().any()
# Out:
# False

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### we can see that there are no duplicate records in any of the tables and collisions and vehicles tables do not have any null values in any of the unique identifier columns. However, there are some null values in person id in Persons table. This column will be imputed with appropriate value data transformation script
